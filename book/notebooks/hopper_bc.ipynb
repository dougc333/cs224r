# %% [markdown]
# Imitation Learning BC/DAgg

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/'Colab Notebooks'
# Out:
# /content/drive/MyDrive/Colab Notebooks
