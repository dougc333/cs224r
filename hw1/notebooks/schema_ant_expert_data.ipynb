# %% [markdown]
# # Schema Ant pkl expert data
#
# <p>Feed the schema output into chatGPT</p>

# %%
import os
os.getcwd()
# Out:
# '/Users/dc/cs224r/hw1/notebooks'

# %%
import pickle
# cs224r/expert_data/expert_data_Ant-v4.pkl
with open("/Users/dc/cs224r/hw1/cs224r/expert_data/expert_data_Ant-v4.pkl", "rb") as f:
    obj = pickle.load(f)

#print(f'{type(obj)}, {len(obj)}')
#print(type(obj[0]),type(obj[1]))
#print(obj[0].keys(), obj[1].keys())


with open("/Users/dc/cs224r/hw1/cs224r/policies/experts/Ant.pkl", "rb") as f:
    obj = pickle.load(f)

print('loading Ant.pkl')
print(f"obj, {type(obj)}")
print(obj.keys())

policy_obj = obj["GaussianPolicy"]
print("GaussianPolicy type:", type(policy_obj))
print("GaussianPolicy keys:", policy_obj.keys())


print(type(policy_obj["hidden"]))
print("policy_obj['hidden'].keys():",policy_obj["hidden"].keys())
print("type(policy_obj['hidden']['FeedforwardNet']:",type(policy_obj["hidden"]["FeedforwardNet"]))
print("policy_obj['hidden']['FeedforwardNet'].keys():",policy_obj["hidden"]["FeedforwardNet"].keys())
# layer_2 layer_0
print("type(policy_obj['hidden']['FeedforwardNet']['layer_2']):",type(policy_obj["hidden"]["FeedforwardNet"]["layer_2"]))
print("type(policy_obj['hidden']['FeedforwardNet']['layer_0']):",type(policy_obj["hidden"]["FeedforwardNet"]["layer_0"]))
#
#
print("type(policy_obj['hidden']['FeedforwardNet']['layer_2'])",type(policy_obj["hidden"]["FeedforwardNet"]["layer_2"]))
print("type(policy_obj['hidden']['FeedforwardNet']['layer_0'])",type(policy_obj["hidden"]["FeedforwardNet"]["layer_0"]))

print("policy_obj['hidden']['FeedforwardNet']['layer_2']['AffineLayer'].keys())",policy_obj["hidden"]["FeedforwardNet"]["layer_2"]["AffineLayer"].keys())
print("policy_obj['hidden']['FeedforwardNet']['layer_2']['AffineLayer']['W'])",type(policy_obj["hidden"]["FeedforwardNet"]["layer_2"]["AffineLayer"]['W']))
print("policy_obj['hidden']['FeedforwardNet']['layer_2']['AffineLayer']['b'])",type(policy_obj["hidden"]["FeedforwardNet"]["layer_2"]["AffineLayer"]['b']))


print("policy_obj['hidden']['FeedforwardNet']['layer_2']['AffineLayer']['W'].shape:",policy_obj["hidden"]["FeedforwardNet"]["layer_2"]["AffineLayer"]['W'].shape)
print("policy_obj['hidden']['FeedforwardNet']['layer_2']['AffineLayer']['b'].shape:",policy_obj["hidden"]["FeedforwardNet"]["layer_2"]["AffineLayer"]['b'].shape)



print("policy_obj['hidden']['FeedforwardNet']['layer_0']['AffineLayer'].keys())",policy_obj["hidden"]["FeedforwardNet"]["layer_0"]["AffineLayer"].keys())
print("policy_obj['hidden']['FeedforwardNet']['layer_0']['AffineLayer']['W']",type(policy_obj["hidden"]["FeedforwardNet"]["layer_0"]["AffineLayer"]['W']))
print("policy_obj['hidden']['FeedforwardNet']['layer_0']['AffineLayer']['b'])",type(policy_obj["hidden"]["FeedforwardNet"]["layer_0"]["AffineLayer"]['b']))

print("policy_obj['hidden']['FeedforwardNet']['layer_0']['AffineLayer']['W'].shape:",policy_obj["hidden"]["FeedforwardNet"]["layer_0"]["AffineLayer"]['W'].shape)
print("policy_obj['hidden']['FeedforwardNet']['layer_0']['AffineLayer']['b'].shape:",policy_obj["hidden"]["FeedforwardNet"]["layer_0"]["AffineLayer"]['b'].shape)


#
#
##
print(type(policy_obj["out"]))
print(policy_obj["out"].keys())
print("type(policy_obj['out']['AffineLayer']):",type(policy_obj["out"]["AffineLayer"]))
print("policy_obj['out']['AffineLayer'].keys():",policy_obj["out"]["AffineLayer"].keys())
print("type(policy_obj['out']['AffineLayer']['W']):",type(policy_obj["out"]["AffineLayer"]["W"]))
print("type(policy_obj['out']['AffineLayer']['b']):",type(policy_obj["out"]["AffineLayer"]["b"]))
print("policy_obj['out']['AffineLayer']['W'].shape:",policy_obj["out"]["AffineLayer"]["W"].shape)
print("policy_obj['out']['AffineLayer']['b'].shape:",policy_obj["out"]["AffineLayer"]["b"].shape)

print(type(policy_obj["obsnorm"]))
print(policy_obj["obsnorm"].keys())
print("type(policy_obj['obsnorm']['Standardizer']):",type(policy_obj["obsnorm"]["Standardizer"]))
print("policy_obj['obsnorm']['Standardizer'].keys():",policy_obj["obsnorm"]["Standardizer"].keys())
print("type(policy_obj['obsnorm']['Standardizer']['mean_1_D']):",type(policy_obj["obsnorm"]["Standardizer"]["mean_1_D"]))
print("type(policy_obj['obsnorm']['Standardizer']['meansq_1_D']):",type(policy_obj["obsnorm"]["Standardizer"]["meansq_1_D"]))
print("policy_obj['obsnorm']['Standardizer']['mean_1_D'].shape:",policy_obj["obsnorm"]["Standardizer"]["mean_1_D"].shape)
print("policy_obj['obsnorm']['Standardizer']['meansq_1_D'].shape:",policy_obj["obsnorm"]["Standardizer"]["meansq_1_D"].shape)
print("fin obs_norm standardizer mean_1_D and meansq_1_D" )


print("type(policy_obj['obsnorm']['Standardizer']['count']):",type(policy_obj["obsnorm"]["Standardizer"]["count"]))
print("policy_obj['obsnorm']['Standardizer']['count'].shape:",policy_obj["obsnorm"]["Standardizer"]["count"].shape)
print("fin obsnorm Standardizer count")

print(type(policy_obj["logstdevs_1_Da"])) #numpy array
print("policy_obj['logstdevs_1_Da'].shape:",policy_obj["logstdevs_1_Da"].shape)
print("fin logstdevs_1_Da")

print(type(policy_obj["out"]))
print(policy_obj["out"].keys())
print("type(policy_obj['out']['AffineLayer']):",type(policy_obj["out"]["AffineLayer"]))
print("policy_obj['out']['AffineLayer'].keys():",policy_obj["out"]["AffineLayer"].keys())
print("type(policy_obj['out']['AffineLayer']['W']):",type(policy_obj["out"]["AffineLayer"]["W"]))
print("type(policy_obj['out']['AffineLayer']['b']):",type(policy_obj["out"]["AffineLayer"]["b"]))

print("fin total")

print("Has attributes:", [a for a in ["get_action", "act", "forward", "__call__"] if hasattr(policy_obj, a)])
print("Some dir() entries:", [x for x in dir(policy_obj) if "act" in x.lower() or "action" in x.lower()][:50])

print("type obj['nonlin_type']:", type(obj['nonlin_type']), obj['nonlin_type'])
# Out:
# loading Ant.pkl
# obj, <class 'dict'>
# dict_keys(['GaussianPolicy', 'nonlin_type'])
# GaussianPolicy type: <class 'dict'>
# GaussianPolicy keys: dict_keys(['hidden', 'obsnorm', 'logstdevs_1_Da', 'out'])
# <class 'dict'>
# policy_obj['hidden'].keys(): dict_keys(['FeedforwardNet'])
# type(policy_obj['hidden']['FeedforwardNet']: <class 'dict'>
# policy_obj['hidden']['FeedforwardNet'].keys(): dict_keys(['layer_2', 'layer_0'])
# type(policy_obj['hidden']['FeedforwardNet']['layer_2']): <class 'dict'>
# type(policy_obj['hidden']['FeedforwardNet']['layer_0']): <class 'dict'>
# type(policy_obj['hidden']['FeedforwardNet']['layer_2']) <class 'dict'>
# type(policy_obj['hidden']['FeedforwardNet']['layer_0']) <class 'dict'>
# policy_obj['hidden']['FeedforwardNet']['layer_2']['AffineLayer'].keys()) dict_keys(['W', 'b'])
# policy_obj['hidden']['FeedforwardNet']['layer_2']['AffineLayer']['W']) <class 'numpy.ndarray'>
# ...
